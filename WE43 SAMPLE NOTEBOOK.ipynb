# %% [markdown]
# ###Let us learn about what is notebook fundamentally

# %% [markdown]
# ####Lets learn about cells (text or code)

# %% [markdown]
# - text (md)
# - code start with magic command (python, scala, pyspark, sql/hql, sh, fs ....)

# %%
# %sql
select * from tbl2;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %% [markdown]
# ####Let us understand scala coding

# %%
# %scala
var a=10
println(a)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Menlo", "Monaco", "Consolas", "Ubuntu Mono", "Source Code Pro", monospace;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">10
# a: Int = 10
# </div>

# %%
# %sh
cat /tmp/driver-env.sh
# Out:
#  CONF_DRIVER_HEAP_SIZE=7254
#  CONF_EXECUTOR_HEAP_SIZE=8278
#  CONF_DBHOME=/databricks
#  CONF_HIVE_CONF_DIR=/databricks/hive/conf
#  CONF_PUBLIC_DNS=10.172.232.65
#  CONF_UI_PORT=40001
#  CONF_MASTER_URL=local[8]
#  CONF_SPARK_JAR_DIR=/mnt/driver-daemon/jars
#  CONF_USE_G1GC_FOR_DRIVER=false
#  CONF_PYSPARK_PYTHON=/databricks/python/bin/python
#  CONF_CLUSTER_GENERATION=1
#  CONF_SPARK_CONF_FILE_PATH=/tmp/custom-spark.conf
#  CONF_DRIVER_WORKING_DIR=/databricks/driver
# ...
